# %% [markdown]
# This a Colaboratory notebook, a document containing information and executable code.

# %% [markdown]
# # Integration with Drive
#
# Colaboratory is integrated with Google Drive. It allows you to share, comment, and collaborate on the same document with multiple people:
#
# * **File->Save a copy in drive** creates a copy of the notebook in Drive.
#
# * **File->Save** saves the File to Drive. **File->Save and checkpoint** pins the version so it doesn't get deleted from the revision history.
#
# * **File->Revision history** shows the notebook's revision history.
#
# * The **Share** button (top-right of the toolbar) allows you to share the notebook and control permissions set on it.

# %% [markdown]
# # Runtime
# To execute the notebook, you must connect to a Runtime by clicking connect on the upper right corner.
#
# This runtime *is* a **Linux** server in a datacenter somewhere. So everything that you do **here** is really done **there**.
#
# **When you stop the runtime everything you have not saved is lost.**
#
# When you finish working you have to remember to stop the runtime, because there is a time limit and to avoid wasting resources. To stop the runtime click **Manage Sessions** on the **Runtime** menu. Once the dialog opens click terminate on the current runtime. It's something like shutting down the computer.

# %% [markdown]
# ## Files
#
# Since everything that we do in colab is done on a remote server, all the files are also stored there. There is a simple file browser on the left column, it can be opened clicking in the 📁 icon.

# %% [markdown]
# # Cells
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it. Double click to edit.
#
# > Google Colab is based on Jupyter Notebooks. You can run Jupyter Notebooks in your computer, there are small differences though.

# %% [markdown]
# ## Code cells
# Below there's a **code cell**. Once you have connected to a Runtime click in the cell to select it and execute the contents clicking the **Play icon** in the left gutter of the cell.
#
# Once the cell has executed a green checkbox icon will be shown on the left.

# %%
10 + 10

# %% [markdown]
# The order in which you execute the cells is important. Notebooks usually have a structure in which you have to run the cells in order and you can't start running the code in the middle.
#
# You can reorder the cells using the arrows that appear when you hover a cell.

# %%
print(message)

# %%
message = "This variable has been initialized"

# %% [markdown]
# Code cells can run Python code like before or execute system commands on the remote machine when preceeded with ! or %. You can use the commands you learnt in the previous course like ls, cd, pwd, ... or pip to install python packages.
#
# In the next cell we list the contents of the current folder.

# %%
# !ls

# %% [markdown]
# ## Cell format

# %% [markdown]
# Code cells can also contain text, double click the next cell to see how it works.

# %%
#@markdown You can't see the code, but tunning this cell will print some text.
print("Hello world!")

# %% [markdown]
# You can even add input parameters that is assigned to parameters.

# %%
#@markdown This cell prints a string multiple times.
text = "Hello world!" #@param {type:"string"}
times = 4 #@param {type:"integer"}

for i in range(times):
  print(text)

# %% [markdown]
# # Google drive
#
# Google Colab can also be connected to Google Drive to facilitate file management. This way your drive content will appear as a folder on the remote server and you can read and write files to it. Let's see how it works.
#
# First we have to authorise the connection by executing the following code.
#
#
# > There will be some warnings ⚠⚠⚠ , and there's a good reason: if you do this, the colab notebook code will have access to all your files there. In this case you can trust me 👼

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Now in the file explorer you will see all your files and folders inside */content/drive/MyDrive* and you can use this path to read and write files.
#
# And, of course, you will be able to access the Drive files from the code.

# %%
# !ls /content/drive/MyDrive

# %% [markdown]
# # Exercise
#
# Import the code for the computational poem challenge and add an input parameter for the text instead of reading values from the terminal.

# %% [markdown]
# # Finalizing
#
# When you finish working you have to remember to **stop the runtime**, because there is a time limit and to avoid wasting resources. To stop the runtime click Manage Sessions on the Runtime menu. Once the dialog opens click terminate on the current runtime.
#
# > But when you stop the runtime everything you have not saved is ⚠ **lost** ⚠, so be sure to **download** everything you want to keep before stopping it.

# %% [markdown]
# # Credits
#
# Estampa https://tallerestampa.com / https://github.com/estampa
